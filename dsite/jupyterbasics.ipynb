# %%
print('Hello Jupyter!')
# Out:
# Hello Jupyter!

# %%
print('Hello Jupyter!')
# Out:
# Hello Jupyter!

# %%
import datetime as dt
dt.datetime.now()
import matplotlib.pyplot as mpl
data = [1,3,5,7,9,11]
mpl.plot(data)
